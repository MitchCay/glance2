# %%
# Testing notebooks setup properly and imports working properly
import pandas as pd
df = pd.read_csv("test_files/testcsv.csv")
df.head()
# Out:
#    a  b  c
# 0  1  2  3

# %%
"""
Everything working... Now lets start preprocessing Transaction History File uploads from my financial services (Amex,
Lake Elmo Bank, Venmo(?)).

Would do this now but I am on a plane and... well personal data. So lets outline some next steps.

    ADD TRANSACTIONS
    ----------------
    1. Extract relevant information from transaction uploads: Amount, date, description, transaction_id(?)
    2. Append needed information to transactions: user_id, transaction_id(?)
    3. Add new entries to db, making sure not to duplicate transactions in table.
    4. Return what? Success or fail to frontend? Any transaction data of new transactions?

    GET TRANSACTIONS - Dont need to sort out how to do this in notebook unless there is specific data formating needed via pandas.
    ------------------------------------------------------------------------------------------------------------------------------
    1. Get all transactions, date range optional?
    2. Return transactions from db

    FUTURE PROJECTION
    -----------------
    1. Simple method: 
        1. Calculate average daily change in finances over last __ period and extend that into a future_df
        2. For each future day look back at last ___ days and make that average change the change for that day, then step.
    2. Smarter method:
        1. Take in recurring expenses (rent, car payment, studen loans) and make the exact adjustment to finances in future on those days.
            Combine this with a simple method to get a more accurate prediction of future finances.
                - Beware of doubling influence of known transactions. i.e. simple method is taking into accout mortgage and so is smart method.
    3. AI Agent you can talk to for input/automatic advice.    
"""
